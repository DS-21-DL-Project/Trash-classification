# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("runs/detect/train/weights/best.pt")

# object classes
classNames = ['Plastic', 'Styrofoam' ,'general' ,'glass', 'metal' ,'paper', 'vinyl']


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Glass, 97.9ms
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 97.9ms inference, 79.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.6ms
# Confidence ---> 0.69
# Class name --> glass
# Speed: 2.1ms preprocess, 7.6ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 13.4ms
# Confidence ---> 0.72
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 2.1ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.5ms
# Confidence ---> 0.71
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.4ms
# Confidence ---> 0.66
# Class name --> glass
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.8ms
# Confidence ---> 0.72
# Class name --> glass
# Speed: 1.0ms preprocess, 6.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.2ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.1ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 2.1ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.3ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.3ms
# Confidence ---> 0.63
# Class name --> glass
# Speed: 1.0ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.7ms
# Confidence ---> 0.6
# Class name --> glass
# Speed: 1.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.3ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 10.6ms
# Confidence ---> 0.58
# Class name --> glass
# Speed: 0.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 6.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 1.5ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 5.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Confidence ---> 0.28
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 7.9ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Confidence ---> 0.28
# Class name --> glass
# Speed: 2.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 7.0ms
# Confidence ---> 0.6
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Confidence ---> 0.31
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 10.3ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 6.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 6.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.4ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 7.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.2ms
# Confidence ---> 0.68
# Class name --> glass
# Speed: 1.5ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.2ms
# Confidence ---> 0.7
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 2.2ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.5ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.7ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.3ms preprocess, 4.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.3ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.1ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.1ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.1ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.1ms
# Confidence ---> 0.71
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.1ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.5ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.65
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.68
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.68
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.5ms
# Confidence ---> 0.7
# Class name --> glass
# Confidence ---> 0.35
# Class name --> glass
# Speed: 0.0ms preprocess, 5.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.65
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.4ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Speed: 1.0ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.1ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 9.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 7.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Confidence ---> 0.33
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 8.0ms
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.38
# Class name --> Styrofoam
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.37
# Class name --> Styrofoam
# Confidence ---> 0.35
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.69
# Class name --> glass
# Confidence ---> 0.38
# Class name --> Styrofoam
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Confidence ---> 0.3
# Class name --> Styrofoam
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 5.0ms
# Confidence ---> 0.68
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 4.9ms
# Confidence ---> 0.63
# Class name --> glass
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.2ms
# Confidence ---> 0.7
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Confidence ---> 0.28
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.1ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 7.0ms
# Confidence ---> 0.63
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.3ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.49
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 0.9ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.0ms
# Confidence ---> 0.5
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.56
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 8.0ms
# Confidence ---> 0.5
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 10.0ms
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.42
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.2ms
# Confidence ---> 0.39
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 8.0ms
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Paper, 6.0ms
# Confidence ---> 0.37
# Class name --> Styrofoam
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 5.6ms
# Confidence ---> 0.57
# Class name --> Styrofoam
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 9.0ms
# Confidence ---> 0.42
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.44
# Class name --> glass
# Confidence ---> 0.39
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.39
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.3ms
# Confidence ---> 0.42
# Class name --> glass
# Speed: 1.0ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.0ms
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.0ms
# Confidence ---> 0.44
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 10.0ms
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 1 Paper, 6.0ms
# Confidence ---> 0.34
# Class name --> general
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 1 Paper, 5.0ms
# Confidence ---> 0.41
# Class name --> general
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 7.0ms
# Confidence ---> 0.47
# Class name --> general
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 6.0ms
# Confidence ---> 0.48
# Class name --> general
# Confidence ---> 0.29
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 5.0ms
# Confidence ---> 0.48
# Class name --> general
# Confidence ---> 0.29
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 1 Paper, 7.0ms
# Confidence ---> 0.42
# Class name --> general
# Confidence ---> 0.37
# Class name --> Styrofoam
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.32
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.38
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 1 Plastic, 4.9ms
# Confidence ---> 0.35
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Confidence ---> 0.27
# Class name --> metal
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.1ms
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.34
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 9.0ms
# Confidence ---> 0.34
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 10.1ms
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.1ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.9ms
# Confidence ---> 0.4
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.5ms
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 5.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.0ms
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 9.0ms
# Confidence ---> 0.44
# Class name --> glass
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.2ms
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 10.0ms
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.39
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 0.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.8ms
# Confidence ---> 0.39
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 2.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.31
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.0ms
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.2ms
# Confidence ---> 0.31
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.41
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.9ms
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.0ms preprocess, 4.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.31
# Class name --> glass
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.32
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.9ms
# Confidence ---> 0.32
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.47
# Class name --> glass
# Speed: 0.0ms preprocess, 5.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.5
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 9.0ms
# Confidence ---> 0.74
# Class name --> glass
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.0ms
# Confidence ---> 0.51
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.2ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.0ms preprocess, 4.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 11.0ms
# Confidence ---> 0.61
# Class name --> glass
# Speed: 1.1ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 11.8ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 11.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 10.5ms
# Confidence ---> 0.56
# Class name --> glass
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.8ms
# Confidence ---> 0.56
# Class name --> glass
# Speed: 1.0ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 7.0ms
# Confidence ---> 0.6
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.1ms
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.6ms
# Confidence ---> 0.63
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.1ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.2ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 5.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.1ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Speed: 1.1ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 9.2ms
# Confidence ---> 0.4
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 9.5ms
# Confidence ---> 0.51
# Class name --> glass
# Speed: 0.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.4ms
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.38
# Class name --> glass
# Confidence ---> 0.3
# Class name --> glass
# Speed: 1.3ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 10.0ms
# Confidence ---> 0.35
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.2ms
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.0ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 9.5ms
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 0.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.5ms
# Confidence ---> 0.32
# Class name --> glass
# Speed: 1.1ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 8.0ms
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 6.0ms
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Paper, 5.0ms
# Confidence ---> 0.43
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.46
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.4
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 4.0ms
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 2.0ms preprocess, 4.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.54
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.65
# Class name --> glass
# Confidence ---> 0.57
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.9ms
# Confidence ---> 0.65
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Speed: 1.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.74
# Class name --> glass
# Confidence ---> 0.51
# Class name --> glass
# Speed: 0.9ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.63
# Class name --> glass
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Speed: 1.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.77
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.74
# Class name --> glass
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Speed: 0.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.6
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.72
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.44
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Speed: 0.9ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.2ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.44
# Class name --> glass
# Speed: 1.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.63
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 9.1ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Speed: 1.1ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 4.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.44
# Class name --> glass
# Speed: 1.0ms preprocess, 4.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.67
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.74
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.76
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.77
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.78
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 8.0ms
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.49
# Class name --> general
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 8.0ms
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.34
# Class name --> general
# Confidence ---> 0.27
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 10.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.27
# Class name --> general
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 9.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.32
# Class name --> general
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Speed: 4.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.4ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 8.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.1ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 8.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 10.3ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Speed: 1.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 12.0ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 10.0ms
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 2.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Speed: 2.5ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 11.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Speed: 2.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Speed: 1.1ms preprocess, 5.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Speed: 4.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.46
# Class name --> glass
# Confidence ---> 0.4
# Class name --> glass
# Speed: 1.2ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.9ms
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Speed: 4.1ms preprocess, 5.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.5ms
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Speed: 2.6ms preprocess, 6.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.3ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Speed: 1.1ms preprocess, 9.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.7ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.5ms preprocess, 6.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.6ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Speed: 2.5ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.7ms
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Speed: 1.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.5ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.9ms
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Confidence ---> 0.39
# Class name --> glass
# Speed: 1.0ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.0ms
# ...
#
# 0: 480x640 3 Papers, 6.0ms
# Confidence ---> 0.74
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 2.0ms preprocess, 6.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.68
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 12.5ms
# Confidence ---> 0.75
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 9.0ms
# Confidence ---> 0.76
# Class name --> glass
# Confidence ---> 0.62
# Class name --> glass
# Confidence ---> 0.33
# Class name --> glass
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.66
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.81
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.0ms
# Confidence ---> 0.79
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 7.1ms
# Confidence ---> 0.75
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Speed: 1.0ms preprocess, 7.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 3 Papers, 10.6ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.38
# Class name --> glass
# Confidence ---> 0.28
# Class name --> Styrofoam
# Confidence ---> 0.27
# Class name --> general
# Speed: 2.0ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 7.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.31
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 3 Papers, 11.0ms
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.27
# Class name --> general
# Confidence ---> 0.26
# Class name --> Styrofoam
# Speed: 3.0ms preprocess, 11.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 10.0ms
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 11.0ms
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.37
# Class name --> glass
# Confidence ---> 0.31
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 7.0ms
# Confidence ---> 0.57
# Class name --> glass
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.3
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 7.0ms
# Confidence ---> 0.46
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Confidence ---> 0.32
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 10.0ms
# Confidence ---> 0.52
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Confidence ---> 0.36
# Class name --> glass
# Confidence ---> 0.3
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 10.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 10.0ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.4
# Class name --> glass
# Confidence ---> 0.26
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 8.0ms
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Confidence ---> 0.39
# Class name --> glass
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 12.0ms
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.0ms
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 6.3ms
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.0ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.5ms
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.39
# Class name --> glass
# Confidence ---> 0.26
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 5.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 7.4ms
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.31
# Class name --> Styrofoam
# Speed: 1.1ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.0ms
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.43
# Class name --> glass
# Confidence ---> 0.41
# Class name --> glass
# Confidence ---> 0.3
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.68
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.44
# Class name --> glass
# Confidence ---> 0.3
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.0ms
# Confidence ---> 0.78
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.38
# Class name --> Styrofoam
# Confidence ---> 0.31
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 12.0ms
# Confidence ---> 0.74
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.35
# Class name --> glass
# Confidence ---> 0.33
# Class name --> Styrofoam
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.8
# Class name --> glass
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.34
# Class name --> Styrofoam
# Confidence ---> 0.34
# Class name --> glass
# Speed: 1.1ms preprocess, 5.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.7ms
# Confidence ---> 0.76
# Class name --> glass
# Confidence ---> 0.54
# Class name --> glass
# Confidence ---> 0.41
# Class name --> Styrofoam
# Confidence ---> 0.37
# Class name --> glass
# Speed: 1.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 5.0ms
# Confidence ---> 0.8
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.35
# Class name --> Styrofoam
# Confidence ---> 0.34
# Class name --> glass
# Speed: 2.1ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 7.0ms
# Confidence ---> 0.84
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Confidence ---> 0.34
# Class name --> glass
# Confidence ---> 0.33
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.0ms
# Confidence ---> 0.83
# Class name --> glass
# Confidence ---> 0.5
# Class name --> glass
# Confidence ---> 0.33
# Class name --> Styrofoam
# Confidence ---> 0.29
# Class name --> glass
# Speed: 0.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 3 Papers, 4.9ms
# Confidence ---> 0.85
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Confidence ---> 0.31
# Class name --> glass
# Confidence ---> 0.29
# Class name --> Styrofoam
# Confidence ---> 0.28
# Class name --> general
# Speed: 1.0ms preprocess, 4.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.85
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 12.0ms
# Confidence ---> 0.83
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.32
# Class name --> glass
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.86
# Class name --> glass
# Confidence ---> 0.47
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.0ms
# Confidence ---> 0.88
# Class name --> glass
# Confidence ---> 0.55
# Class name --> glass
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 7.0ms
# Confidence ---> 0.89
# Class name --> glass
# Confidence ---> 0.63
# Class name --> glass
# Confidence ---> 0.42
# Class name --> glass
# Confidence ---> 0.3
# Class name --> general
# Speed: 2.4ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 6.0ms
# Confidence ---> 0.85
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.51
# Class name --> glass
# Confidence ---> 0.32
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 3 Papers, 8.1ms
# Confidence ---> 0.86
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Confidence ---> 0.44
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 1 Metal, 3 Papers, 6.0ms
# Confidence ---> 0.9
# Class name --> glass
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.45
# Class name --> Styrofoam
# Confidence ---> 0.4
# Class name --> glass
# Confidence ---> 0.33
# Class name --> general
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 6.0ms
# Confidence ---> 0.89
# Class name --> glass
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.4
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 8.0ms
# Confidence ---> 0.93
# Class name --> glass
# Confidence ---> 0.64
# Class name --> glass
# Confidence ---> 0.32
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Glass, 2 Papers, 4.3ms
# Confidence ---> 0.86
# Class name --> glass
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.27
# Class name --> Styrofoam
# Speed: 1.0ms preprocess, 4.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.82
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 2 Papers, 6.0ms
# Confidence ---> 0.84
# Class name --> glass
# Confidence ---> 0.58
# Class name --> glass
# Confidence ---> 0.32
# Class name --> general
# Speed: 2.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.82
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 2 Papers, 4.1ms
# Confidence ---> 0.88
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Confidence ---> 0.29
# Class name --> general
# Speed: 2.0ms preprocess, 4.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 5.0ms
# Confidence ---> 0.86
# Class name --> glass
# Confidence ---> 0.53
# Class name --> glass
# Confidence ---> 0.34
# Class name --> general
# Confidence ---> 0.26
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Papers, 5.0ms
# Confidence ---> 0.86
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.28
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 7.0ms
# Confidence ---> 0.88
# Class name --> glass
# Confidence ---> 0.49
# Class name --> glass
# Confidence ---> 0.27
# Class name --> glass
# Confidence ---> 0.26
# Class name --> general
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 2 Papers, 6.1ms
# Confidence ---> 0.88
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Confidence ---> 0.32
# Class name --> general
# Speed: 2.0ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 8.0ms
# Confidence ---> 0.8
# Class name --> glass
# Confidence ---> 0.45
# Class name --> glass
# Confidence ---> 0.29
# Class name --> glass
# Confidence ---> 0.28
# Class name --> general
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Metal, 3 Papers, 6.5ms
# Confidence ---> 0.87
# Class name --> glass
# Confidence ---> 0.59
# Class name --> glass
# Confidence ---> 0.27
# Class name --> general
# Confidence ---> 0.26
# Class name --> glass
# Speed: 2.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 6.0ms
# Confidence ---> 0.8
# Class name --> glass
# Confidence ---> 0.6
# Class name --> glass
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 5.0ms
# Confidence ---> 0.61
# Class name --> glass
# Confidence ---> 0.56
# Class name --> glass
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 8.1ms
# Confidence ---> 0.79
# Class name --> glass
# Confidence ---> 0.57
# Class name --> glass
# Speed: 1.6ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Papers, 7.2ms
# Confidence ---> 0.7
# Class name --> glass
# Confidence ---> 0.48
# Class name --> glass
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
